# %% [markdown]
# <a href="https://colab.research.google.com/github/pilarandre25/geocoding/blob/main/geocoding.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://raw.githubusercontent.com/geografope/geocodificacion-con-python/main/img/banner.png'>

# %% [markdown]
# Este tutorial fue elaboradro por **Geografo.PE**
#
# Redes sociales:
# - Youtube: www.youtube.com/@ambarja
# - Tiktok: https://www.tiktok.com/@geografo.pe
# - Linkdin: https://www.linkedin.com/in/antonybarja/
# - GitHub: https://github.com/geografope
#
# Para más información, puedes visitar mi pagina personal:*https://geografo.pe*

# %% [markdown]
# ### **1.Instalación de librerias a utilizar**

# %%
# !pip install geopy
# !pip install pandas
# !pip install geopandas
# !pip install mapclassify
# Out:
# Requirement already satisfied: geopy in /usr/local/lib/python3.11/dist-packages (2.4.1)
# Requirement already satisfied: geographiclib<3,>=1.52 in /usr/local/lib/python3.11/dist-packages (from geopy) (2.0)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: geopandas in /usr/local/lib/python3.11/dist-packages (1.0.1)
# Requirement already satisfied: numpy>=1.22 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.0.2)
# Requirement already satisfied: pyogrio>=0.7.2 in /usr/local/lib/python3.11/dist-packages (from geopandas) (0.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from geopandas) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.2.2)
# Requirement already satisfied: pyproj>=3.3.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from geopandas) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=1.4.0->geopandas) (2025.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.11/dist-packages (from pyogrio>=0.7.2->geopandas) (2025.6.15)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas) (1.17.0)
# Collecting mapclassify
#   Downloading mapclassify-2.9.0-py3-none-any.whl.metadata (3.1 kB)
# Requirement already satisfied: networkx>=3.2 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (3.5)
# Requirement already satisfied: numpy>=1.26 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (2.0.2)
# Requirement already satisfied: pandas>=2.1 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (2.2.2)
# Requirement already satisfied: scikit-learn>=1.4 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.6.1)
# Requirement already satisfied: scipy>=1.12 in /usr/local/lib/python3.11/dist-packages (from mapclassify) (1.15.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->mapclassify) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=2.1->mapclassify) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapclassify) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn>=1.4->mapclassify) (3.6.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas>=2.1->mapclassify) (1.17.0)
# Downloading mapclassify-2.9.0-py3-none-any.whl (286 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 286.7/286.7 kB 6.5 MB/s eta 0:00:00
# Installing collected packages: mapclassify
# Successfully installed mapclassify-2.9.0

# %% [markdown]
# ### **2.Llamado o activación de librerias**

# %%
from geopy.geocoders import Nominatim, ArcGIS, MapBox
import pandas as pd
import geopandas as gpd
from functools import partial

# %% [markdown]
# ### **3.Lectura de los datos crudos en formato excel**

# %%
url = '/content/EJEMPLO.xlsx'
rawdata = pd.read_excel(url)

# %%
rawdata.shape
# Out:
# (10, 13)

# %% [markdown]
# ### **4.Función para estandarizar extructura de texto para geocodificar**

# %%
# Forma estandar de la estructura del texto para geodificar con Nominatim:
# direccion,distrito,provincia,departamento,pais
# Ejemplo: "Calle Los Angeles 123, Carabayllo, Lima, Lima, Perú"
def concatenar_campos(row):
    return f"{row['Addr']}"

# %%
rawdata['nogeo'] = rawdata.apply(concatenar_campos, axis= 1)
rawdata.head()
# Out:
#    id  COD_DPTO  COD_MPIO  COD_DPTO_num  COD_MPIO_num           Address  \
# 0   1         5      5001             5          5001   CR 52 # 30 - 20
# 1   2         5      5001             5          5001      CRR 80 48 00
# 2   3         5      5001             5          5001   CR 51 # 79 - 10
# 3   4         5      5001             5          5001    CRR 64 C 88 00
# 4   5         5      5001             5          5001  CR 63 # 123 - 12
#
#        City     Region   Country  \
# 0  Medellín  Antioquia  Colombia
# 1  Medellín  Antioquia  Colombia
# 2  Medellín  Antioquia  Colombia
# 3  Medellín  Antioquia  Colombia
# 4  Medellín  Antioquia  Colombia
#
#                                               Addr TIPO_USARIO ESTADO_CIVIL  \
# 0   CR 52 # 30 - 20, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 1      CRR 80 48 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 2   CR 51 # 79 - 10, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 3    CRR 64 C 88 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 4  CR 63 # 123 - 12, Medellín, Antioquia, Colombia    Afiliado      Soltero
#
#   GENERO                                            nogeo
# 0      F   CR 52 # 30 - 20, Medellín, Antioquia, Colombia
# 1      M      CRR 80 48 00, Medellín, Antioquia, Colombia
# 2      F   CR 51 # 79 - 10, Medellín, Antioquia, Colombia
# 3      M    CRR 64 C 88 00, Medellín, Antioquia, Colombia
# 4      F  CR 63 # 123 - 12, Medellín, Antioquia, Colombia

# %%
rawdata_for_osm = rawdata.copy()
rawdata_for_mapbox = rawdata.copy()
rawdata_for_arcgis = rawdata.copy()

# %% [markdown]
# ### **5.Gecodificación directa con la API de OSM**
# - Nominatim: Es una herramienta open source que sirve para realizar proceso de geocodificación a través de OpenSteetMap.
# Referencia: *https://github.com/osm-search/Nominatim*

# %%
# Gecodificación directa
geolocator = Nominatim(user_agent="geografo_pe",timeout = 5)
geocode = partial(geolocator.geocode, language="es")
def tidygeocode(row):
    location = geolocator.geocode(row['nogeo'])
    if location:
        return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
    else:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
rawdata_for_osm[['latitude', 'longitude']] = rawdata_for_osm.apply(tidygeocode, axis=1)

# %%
rawdata_for_osm
# Out:
#    id  COD_DPTO  COD_MPIO  COD_DPTO_num  COD_MPIO_num  \
# 0   1         5      5001             5          5001
# 1   2         5      5001             5          5001
# 2   3         5      5001             5          5001
# 3   4         5      5001             5          5001
# 4   5         5      5001             5          5001
# 5   6         5      5001             5          5001
# 6   7         5      5001             5          5001
# 7   8         5      5001             5          5001
# 8   9         5      5001             5          5001
# 9  10         5      5001             5          5001
#
#                        Address      City     Region   Country  \
# 0              CR 52 # 30 - 20  Medellín  Antioquia  Colombia
# 1                 CRR 80 48 00  Medellín  Antioquia  Colombia
# 2              CR 51 # 79 - 10  Medellín  Antioquia  Colombia
# 3               CRR 64 C 88 00  Medellín  Antioquia  Colombia
# 4             CR 63 # 123 - 12  Medellín  Antioquia  Colombia
# 5   CALLE 16 A SUR CARRERA 9 F  Medellín  Antioquia  Colombia
# 6                 BUENOS AIRES  Medellín  Antioquia  Colombia
# 7                  CR 46 CL 50  Medellín  Antioquia  Colombia
# 8              CL 67 # 56 -22   Medellín  Antioquia  Colombia
# 9              CR 72 # 27 - 22  Medellín  Antioquia  Colombia
#
#                                                 Addr TIPO_USARIO ESTADO_CIVIL  \
# 0     CR 52 # 30 - 20, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 1        CRR 80 48 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 2     CR 51 # 79 - 10, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 3      CRR 64 C 88 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 4    CR 63 # 123 - 12, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 5   CALLE 16 A SUR CARRERA 9 F, Medellín, Antioqu...    Afiliado       Casado
# 6        BUENOS AIRES, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 7         CR 46 CL 50, Medellín, Antioquia, Colombia    Afiliado       Casado
# 8     CL 67 # 56 -22 , Medellín, Antioquia, Colombia    Afiliado      Soltero
# 9     CR 72 # 27 - 22, Medellín, Antioquia, Colombia    Afiliado       Casado
#
#   GENERO                                              nogeo  latitude  \
# 0      F     CR 52 # 30 - 20, Medellín, Antioquia, Colombia       NaN
# 1      M        CRR 80 48 00, Medellín, Antioquia, Colombia       NaN
# 2      F     CR 51 # 79 - 10, Medellín, Antioquia, Colombia       NaN
# 3      M      CRR 64 C 88 00, Medellín, Antioquia, Colombia       NaN
# 4      F    CR 63 # 123 - 12, Medellín, Antioquia, Colombia       NaN
# 5      M   CALLE 16 A SUR CARRERA 9 F, Medellín, Antioqu...       NaN
# 6      F        BUENOS AIRES, Medellín, Antioquia, Colombia  6.230229
# 7      M         CR 46 CL 50, Medellín, Antioquia, Colombia  6.252770
# 8      F     CL 67 # 56 -22 , Medellín, Antioquia, Colombia  6.264485
# 9      M     CR 72 # 27 - 22, Medellín, Antioquia, Colombia       NaN
#
#    longitude
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
# 5        NaN
# 6 -75.556921
# 7 -75.573975
# 8 -75.566958
# 9        NaN

# %% [markdown]
# ### **6.Visualización de datos espaciales**

# %%
# Eliminar datos vacios
geo_rawdata = rawdata_for_osm.dropna()
# Dataframe a gepandas
geo_rawdata = gpd.GeoDataFrame(data = geo_rawdata, geometry=gpd.points_from_xy(geo_rawdata.longitude, geo_rawdata.latitude),crs = 4326)

# %%
# Visualización interactiva
geo_rawdata.explore(tiles = "Esri.WorldImagery",marker_kwds={'radius': 10} )
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cfa9f42a629cc1bf890bb2c38cab0696 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cfa9f42a629cc1bf890bb2c38cab0696&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cfa9f42a629cc1bf890bb2c38cab0696 = L.map(
#                 &quot;map_cfa9f42a629cc1bf890bb2c38cab0696&quot;,
#                 {
#                     center: [6.2473573, -75.56544775],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_cfa9f42a629cc1bf890bb2c38cab0696);
#
#
#
#
#
#             var tile_layer_d4f3b3ac439b94781c8c83989050cc12 = L.tileLayer(
#                 &quot;https://server.arcgisonline.com/ArcGIS/rest/services/World_Imagery/MapServer/tile/{z}/{y}/{x}&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 18,
#   &quot;maxNativeZoom&quot;: 18,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;Tiles \u0026copy; Esri \u0026mdash; Source: Esri, i-cubed, USDA, USGS, AEX, GeoEye, Getmapping, Aerogrid, IGN, IGP, UPR-EGP, and the GIS User Community&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d4f3b3ac439b94781c8c83989050cc12.addTo(map_cfa9f42a629cc1bf890bb2c38cab0696);
#
#
#             map_cfa9f42a629cc1bf890bb2c38cab0696.fitBounds(
#                 [[6.2302293, -75.5739748], [6.2644853, -75.5569207]],
#                 {}
#             );
#
#
#         function geo_json_c752b1a688768dcd9ed3b10237ed346b_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_c752b1a688768dcd9ed3b10237ed346b_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_c752b1a688768dcd9ed3b10237ed346b_pointToLayer(feature, latlng) {
#             var opts = {
#   &quot;stroke&quot;: true,
#   &quot;color&quot;: &quot;#3388ff&quot;,
#   &quot;weight&quot;: 3,
#   &quot;opacity&quot;: 1.0,
#   &quot;lineCap&quot;: &quot;round&quot;,
#   &quot;lineJoin&quot;: &quot;round&quot;,
#   &quot;dashArray&quot;: null,
#   &quot;dashOffset&quot;: null,
#   &quot;fill&quot;: true,
#   &quot;fillColor&quot;: &quot;#3388ff&quot;,
#   &quot;fillOpacity&quot;: 0.2,
#   &quot;fillRule&quot;: &quot;evenodd&quot;,
#   &quot;bubblingMouseEvents&quot;: true,
#   &quot;radius&quot;: 10,
# };
#
#             let style = geo_json_c752b1a688768dcd9ed3b10237ed346b_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_c752b1a688768dcd9ed3b10237ed346b_onEachFeature(feature, layer) {
#
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_c752b1a688768dcd9ed3b10237ed346b.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_c752b1a688768dcd9ed3b10237ed346b_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_c752b1a688768dcd9ed3b10237ed346b = L.geoJson(null, {
#                 onEachFeature: geo_json_c752b1a688768dcd9ed3b10237ed346b_onEachFeature,
#
#                 style: geo_json_c752b1a688768dcd9ed3b10237ed346b_styler,
#                 pointToLayer: geo_json_c752b1a688768dcd9ed3b10237ed346b_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_c752b1a688768dcd9ed3b10237ed346b_add (data) {
#             geo_json_c752b1a688768dcd9ed3b10237ed346b
#                 .addData(data);
#         }
#             geo_json_c752b1a688768dcd9ed3b10237ed346b_add({&quot;bbox&quot;: [-75.5739748, 6.2302293, -75.5569207, 6.2644853], &quot;features&quot;: [{&quot;bbox&quot;: [-75.5569207, 6.2302293, -75.5569207, 6.2302293], &quot;geometry&quot;: {&quot;coordinates&quot;: [-75.5569207, 6.2302293], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;6&quot;, &quot;properties&quot;: {&quot;Addr&quot;: &quot;BUENOS AIRES, Medell\u00edn, Antioquia, Colombia&quot;,

# %% [markdown]
# ### **7.Geocodificación inversa**

# %%
# Geocodificación indirecta
def tidygeocode_inv(row):
  adress = geolocator.reverse([row['latitude'],row['longitude']])
  return(str(adress))

# %%
geocode_inv = geo_rawdata.copy()

# %%
geocode_inv['direccion_geo_inv'] = geocode_inv.apply(tidygeocode_inv, axis = 1)

# %%
geocode_inv = geocode_inv.drop(columns=['geometry'])
geocode_inv = gpd.GeoDataFrame(data = geocode_inv, geometry=gpd.points_from_xy(geo_rawdata.longitude, geo_rawdata.latitude),crs = 4326)

# %%
geocode_inv

# %% [markdown]
# ### **8.Exportar datos espaciales**

# %%
# Exportar datos en formato gpkg
geo_rawdata.to_file('geocoding_directo.gpkg')
geocode_inv.to_file('geocoding_inverso.gpkg')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-30-3434795597.py in <cell line: 0>()
#       1 # Exportar datos en formato gpkg
#       2 geo_rawdata.to_file('geocoding_directo.gpkg')
# ----> 3 geocode_inv.to_file('geocoding_inverso.gpkg')
#
# NameError: name 'geocode_inv' is not defined

# %% [markdown]
# ### **9.Gecodificación usando la API de MapBox**
# Para poder optener nuestra API de MapBox tenemos que registrarnos en el siguiente enlace:
#  - Registro: *https://account.mapbox.com/auth/signup/*
#  - Activar API: *https://account.mapbox.com/access-tokens/create*
#
# #### *Geocodificación gratis: 100 000 al mes*

# %%
api_mapbox = 'PON_TU_API_KEY_AQUI'
geolocator = MapBox(api_key = api_mapbox)
def tidygeocode(row):
    location = geolocator.geocode(row['nogeo'])
    if location:
        return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
    else:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
rawdata_for_mapbox[['latitude', 'longitude']] = rawdata_for_mapbox.apply(tidygeocode, axis=1)
# Out:
# ---------------------------------------------------------------------------
# AdapterHTTPError                          Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     367             if is_json:
# --> 368                 result = self.adapter.get_json(url, timeout=timeout, headers=req_headers)
#     369             else:
#
# /usr/local/lib/python3.11/dist-packages/geopy/adapters.py in get_json(self, url, timeout, headers)
#     471     def get_json(self, url, *, timeout, headers):
# --> 472         resp = self._request(url, timeout=timeout, headers=headers)
#     473         try:
#
# /usr/local/lib/python3.11/dist-packages/geopy/adapters.py in _request(self, url, timeout, headers)
#     499             if resp.status_code >= 400:
# --> 500                 raise AdapterHTTPError(
#     501                     "Non-successful status code %s" % resp.status_code,
#
# AdapterHTTPError: Non-successful status code 401
#
# The above exception was the direct cause of the following exception:
#
# GeocoderAuthenticationFailure             Traceback (most recent call last)
# /tmp/ipython-input-32-585937147.py in <cell line: 0>()
# ----> 1 rawdata_for_mapbox[['latitude', 'longitude']] = rawdata_for_mapbox.apply(tidygeocode, axis=1)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in apply(self, func, axis, raw, result_type, args, by_row, engine, engine_kwargs, **kwargs)
#   10372             kwargs=kwargs,
#   10373         )
# > 10374         return op.apply().__finalize__(self, method="apply")
#   10375
#   10376     def map(
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply(self)
#     914             return self.apply_raw(engine=self.engine, engine_kwargs=self.engine_kwargs)
#     915
# --> 916         return self.apply_standard()
#     917
#     918     def agg(self):
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_standard(self)
#    1061     def apply_standard(self):
#    1062         if self.engine == "python":
# -> 1063             results, res_index = self.apply_series_generator()
#    1064         else:
#    1065             results, res_index = self.apply_series_numba()
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/apply.py in apply_series_generator(self)
#    1079             for i, v in enumerate(series_gen):
#    1080                 # ignore SettingWithCopy here in case the user mutates
# -> 1081                 results[i] = self.func(v, *self.args, **self.kwargs)
#    1082                 if isinstance(results[i], ABCSeries):
#    1083                     # If we have a view on v, we need to make a copy because
#
# /tmp/ipython-input-31-4058797708.py in tidygeocode(row)
#       2 geolocator = MapBox(api_key = api_mapbox)
#       3 def tidygeocode(row):
# ----> 4     location = geolocator.geocode(row['nogeo'])
#       5     if location:
#       6         return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
#
# /usr/local/lib/python3.11/dist-packages/geopy/geocoders/mapbox.py in geocode(self, query, exactly_one, timeout, proximity, country, language, bbox)
#     172         logger.debug("%s.geocode: %s", self.__class__.__name__, url)
#     173         callback = partial(self._parse_json, exactly_one=exactly_one)
# --> 174         return self._call_geocoder(url, callback, timeout=timeout)
#     175
#     176     def reverse(
#
# /usr/local/lib/python3.11/dist-packages/geopy/geocoders/base.py in _call_geocoder(self, url, callback, timeout, is_json, headers)
#     386                 return callback(result)
#     387         except Exception as error:
# --> 388             res = self._adapter_error_handler(error)
#     389             if res is NONE_RESULT:
#     390                 return None
#
# /usr/local/lib/python3.11/dist-packages/geopy/geocoders/base.py in _adapter_error_handler(self, error)
#     409                 ) from error
#     410             else:
# --> 411                 raise exc_cls(str(error)) from error
#     412         else:
#     413             res = self._geocoder_exception_handler(error)
#
# GeocoderAuthenticationFailure: Non-successful status code 401

# %%
rawdata_for_mapbox
# Out:
#    id  COD_DPTO  COD_MPIO  COD_DPTO_num  COD_MPIO_num  \
# 0   1         5      5001             5          5001
# 1   2         5      5001             5          5001
# 2   3         5      5001             5          5001
# 3   4         5      5001             5          5001
# 4   5         5      5001             5          5001
# 5   6         5      5001             5          5001
# 6   7         5      5001             5          5001
# 7   8         5      5001             5          5001
# 8   9         5      5001             5          5001
# 9  10         5      5001             5          5001
#
#                        Address      City     Region   Country  \
# 0              CR 52 # 30 - 20  Medellín  Antioquia  Colombia
# 1                 CRR 80 48 00  Medellín  Antioquia  Colombia
# 2              CR 51 # 79 - 10  Medellín  Antioquia  Colombia
# 3               CRR 64 C 88 00  Medellín  Antioquia  Colombia
# 4             CR 63 # 123 - 12  Medellín  Antioquia  Colombia
# 5   CALLE 16 A SUR CARRERA 9 F  Medellín  Antioquia  Colombia
# 6                 BUENOS AIRES  Medellín  Antioquia  Colombia
# 7                  CR 46 CL 50  Medellín  Antioquia  Colombia
# 8              CL 67 # 56 -22   Medellín  Antioquia  Colombia
# 9              CR 72 # 27 - 22  Medellín  Antioquia  Colombia
#
#                                                 Addr TIPO_USARIO ESTADO_CIVIL  \
# 0     CR 52 # 30 - 20, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 1        CRR 80 48 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 2     CR 51 # 79 - 10, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 3      CRR 64 C 88 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 4    CR 63 # 123 - 12, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 5   CALLE 16 A SUR CARRERA 9 F, Medellín, Antioqu...    Afiliado       Casado
# 6        BUENOS AIRES, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 7         CR 46 CL 50, Medellín, Antioquia, Colombia    Afiliado       Casado
# 8     CL 67 # 56 -22 , Medellín, Antioquia, Colombia    Afiliado      Soltero
# 9     CR 72 # 27 - 22, Medellín, Antioquia, Colombia    Afiliado       Casado
#
#   GENERO                                              nogeo
# 0      F     CR 52 # 30 - 20, Medellín, Antioquia, Colombia
# 1      M        CRR 80 48 00, Medellín, Antioquia, Colombia
# 2      F     CR 51 # 79 - 10, Medellín, Antioquia, Colombia
# 3      M      CRR 64 C 88 00, Medellín, Antioquia, Colombia
# 4      F    CR 63 # 123 - 12, Medellín, Antioquia, Colombia
# 5      M   CALLE 16 A SUR CARRERA 9 F, Medellín, Antioqu...
# 6      F        BUENOS AIRES, Medellín, Antioquia, Colombia
# 7      M         CR 46 CL 50, Medellín, Antioquia, Colombia
# 8      F     CL 67 # 56 -22 , Medellín, Antioquia, Colombia
# 9      M     CR 72 # 27 - 22, Medellín, Antioquia, Colombia

# %% [markdown]
# ### **10.Gecodificación usando la API de ArcGIS**
# Para poder optener nuestra API de ArcGIS tenemos que registrarnos en el siguiente enlace:
#  * Registro: *https://developers.arcgis.com/sign-up/*
#  * Activar API: *https://developers.arcgis.com/dashboard/#*
#
# #### *Geocodificación gratis: 20 000 gratis*

# %%
api_arcgis = 'PON_TU_API_KEY_AQUI'
geolocator = ArcGIS(auth_domain = api_arcgis)
def tidygeocode(row):
    location = geolocator.geocode(row['nogeo'])
    if location:
        return pd.Series({'latitude': location.latitude, 'longitude': location.longitude})
    else:
        return pd.Series({'latitude': None, 'longitude': None})

# %%
rawdata_for_arcgis[['latitude', 'longitude']] = rawdata_for_arcgis.apply(tidygeocode, axis=1)
# Out:
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=1)")': /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=+CRR+80+48+00%2C+Medell%C3%ADn%2C+Antioquia%2C+Colombia&f=json&maxLocations=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=1)")': /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=CR+63+%23+123+-+12%2C+Medell%C3%ADn%2C+Antioquia%2C+Colombia&f=json&maxLocations=1
# WARNING:urllib3.connectionpool:Retrying (Retry(total=1, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ReadTimeoutError("HTTPSConnectionPool(host='geocode.arcgis.com', port=443): Read timed out. (read timeout=1)")': /arcgis/rest/services/World/GeocodeServer/findAddressCandidates?singleLine=CR+46+CL+50%2C+Medell%C3%ADn%2C+Antioquia%2C+Colombia&f=json&maxLocations=1

# %%
rawdata_for_arcgis
# Out:
#    id  COD_DPTO  COD_MPIO  COD_DPTO_num  COD_MPIO_num  \
# 0   1         5      5001             5          5001
# 1   2         5      5001             5          5001
# 2   3         5      5001             5          5001
# 3   4         5      5001             5          5001
# 4   5         5      5001             5          5001
# 5   6         5      5001             5          5001
# 6   7         5      5001             5          5001
# 7   8         5      5001             5          5001
# 8   9         5      5001             5          5001
# 9  10         5      5001             5          5001
#
#                        Address      City     Region   Country  \
# 0              CR 52 # 30 - 20  Medellín  Antioquia  Colombia
# 1                 CRR 80 48 00  Medellín  Antioquia  Colombia
# 2              CR 51 # 79 - 10  Medellín  Antioquia  Colombia
# 3               CRR 64 C 88 00  Medellín  Antioquia  Colombia
# 4             CR 63 # 123 - 12  Medellín  Antioquia  Colombia
# 5   CALLE 16 A SUR CARRERA 9 F  Medellín  Antioquia  Colombia
# 6                 BUENOS AIRES  Medellín  Antioquia  Colombia
# 7                  CR 46 CL 50  Medellín  Antioquia  Colombia
# 8              CL 67 # 56 -22   Medellín  Antioquia  Colombia
# 9              CR 72 # 27 - 22  Medellín  Antioquia  Colombia
#
#                                                 Addr TIPO_USARIO ESTADO_CIVIL  \
# 0     CR 52 # 30 - 20, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 1        CRR 80 48 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 2     CR 51 # 79 - 10, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 3      CRR 64 C 88 00, Medellín, Antioquia, Colombia    Afiliado       Casado
# 4    CR 63 # 123 - 12, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 5   CALLE 16 A SUR CARRERA 9 F, Medellín, Antioqu...    Afiliado       Casado
# 6        BUENOS AIRES, Medellín, Antioquia, Colombia    Afiliado      Soltero
# 7         CR 46 CL 50, Medellín, Antioquia, Colombia    Afiliado       Casado
# 8     CL 67 # 56 -22 , Medellín, Antioquia, Colombia    Afiliado      Soltero
# 9     CR 72 # 27 - 22, Medellín, Antioquia, Colombia    Afiliado       Casado
#
#   GENERO                                              nogeo  latitude  \
# 0      F     CR 52 # 30 - 20, Medellín, Antioquia, Colombia  6.298179
# 1      M        CRR 80 48 00, Medellín, Antioquia, Colombia  6.259440
# 2      F     CR 51 # 79 - 10, Medellín, Antioquia, Colombia  6.273509
# 3      M      CRR 64 C 88 00, Medellín, Antioquia, Colombia  6.281505
# 4      F    CR 63 # 123 - 12, Medellín, Antioquia, Colombia  6.187188
# 5      M   CALLE 16 A SUR CARRERA 9 F, Medellín, Antioqu...  6.229070
# 6      F        BUENOS AIRES, Medellín, Antioquia, Colombia  6.240703
# 7      M         CR 46 CL 50, Medellín, Antioquia, Colombia  6.248739
# 8      F     CL 67 # 56 -22 , Medellín, Antioquia, Colombia  6.264740
# 9      M     CR 72 # 27 - 22, Medellín, Antioquia, Colombia  6.229058
#
#    longitude
# 0 -75.557789
# 1 -75.597650
# 2 -75.562313
# 3 -75.571770
# 4 -75.643068
# 5 -75.542464
# 6 -75.556065
# 7 -75.565223
# 8 -75.569720
# 9 -75.592649

# %%
geo_rawdata_for_arcgis = gpd.GeoDataFrame(data = rawdata_for_arcgis, geometry=gpd.points_from_xy(rawdata_for_arcgis.longitude, rawdata_for_arcgis.latitude),crs = 4326)

# %%
geo_rawdata_for_arcgis.to_file('geocoding_directoARCGIS2.gpkg')
